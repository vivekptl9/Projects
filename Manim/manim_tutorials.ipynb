# %%
from manim import *

# %%
# %%manim -qm FirstExample
# class FirstExample(Scene):
#     def construct(self):
#         blue_circle = Circle(color=BLUE, fill_opacity=0.5)
#         green_square = Square(color=GREEN, fill_opacity=0.5)
#         green_square.next_to(blue_circle, RIGHT)
#         self.add(blue_circle, green_square)
# Out:
# Manim Community v0.18.1
# [09/25/24 19:34:22] INFO                                                                   ]8;id=441999;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=177930;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/home/vivek/Projects/Manim/media/images/Manim/FirstExample_M
#                              animCE_v0.18.1.png'
#                     INFO     Rendered FirstExample                                                     ]8;id=753491;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=538490;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations

# %%
# %%manim -qm SecondExample
# class SecondExample(Scene):
#     def construct(self):
#         ax = Axes(x_range=(-3,3),y_range=(-3,3))
#         curve = ax.plot(lambda x:(x+2)*x*(x-2)/2, color=RED)
#         area = ax.get_area(curve,x_range=(-2,0))
#         self.add(ax,curve,area)
# Out:
# Manim Community v0.18.1
# [09/25/24 19:42:12] INFO                                                                   ]8;id=381715;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=417797;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/home/vivek/Projects/Manim/media/images/Manim/SecondExample_
#                              ManimCE_v0.18.1.png'
#                     INFO     Rendered SecondExample                                                    ]8;id=911204;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=326810;file:///home/vivek/Projects/Manim/Menv/lib/python3.11/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations
